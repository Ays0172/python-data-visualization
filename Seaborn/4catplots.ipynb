# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Create a categorical scatter plot of tip by day and sex
sns.catplot(data=tips, x="day", y="total_bill", hue="time", kind="swarm")

# Set the title and labels
plt.title("Total Bill by Day and Time")
plt.xlabel("Day")
plt.ylabel("Total Bill")

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Create a categorical scatter plot of tip by day and sex
sns.catplot(data=tips, x="day", y="total_bill", hue="time", kind="point")

# Set the title and labels
plt.title("Total Bill by Day and Time")
plt.xlabel("Day")
plt.ylabel("Total Bill")

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Create a categorical scatter plot of tip by day and sex
sns.catplot(data=tips, x="day", y="total_bill", hue="time", kind="bar")

# Set the title and labels
plt.title("Total Bill by Day and Time")
plt.xlabel("Day")
plt.ylabel("Total Bill")

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Create a categorical scatter plot of tip by day and sex
sns.catplot(data=tips, x="day", y="total_bill", hue="time", kind="box")

# Set the title and labels
plt.title("Total Bill by Day and Time")
plt.xlabel("Day")
plt.ylabel("Total Bill")

# Show the plot
plt.show()
